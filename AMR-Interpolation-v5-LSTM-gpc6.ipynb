# %% [markdown]
# #### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import struct

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision.transforms as transforms
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %% [markdown]
# #### Useful functions/classes

# %%
### Reads block files in input_dir up to a maximum time step (max), flattens blocks to be 1x, and
### stores them in a nested list of format all_data[spatial_location[time_step[flattened_block_index]]]: 4608x443x512
def process_data(input_dir, max, block_dim):

    all_data = []

    num_blocks = int((256/block_dim) * (96/block_dim) * (96/block_dim))
    for l in range(num_blocks):
        all_data.append([])
        for t in range(74, max):
            all_data[l].append([])
    
    for t in range(74, max):
        filename = input_dir + str(t) + "-" + str(block_dim) + ".raw"
        with open(filename, "rb") as file:
            for l in range(num_blocks):
                data = [] 
                for i in range(block_dim**3):
                    all_data[l][t-74].append(struct.unpack('<f', file.read(4))[0])
        if (t-73) % 10 == 0:
            print("Processed data from first",str(t-73),"time steps")

    return all_data
    
    
### Creates torch tensors of input/target pairs for use in the LSTM. For each target (each timestep), 
### creates an input sequence of the seq_radius steps before and after that target. Output from 
### process_data can be directly input as obs to this function.
def to_sequences(seq_radius, obs):
    x = []
    y = []
    for l in range(len(obs)): # iterate over each location
        lobs = obs[l]
        for i in range(seq_radius, len(lobs) - seq_radius): # iterate over each possible input/target pair
            window = lobs[(i - seq_radius):i] + lobs[i + 1:(i + seq_radius + 1)]
            mid_window = lobs[i]
            window = np.array(window)
            x.append(window)
            y.append(mid_window)
    x = np.array(x)
    y = np.array(y)
    return torch.tensor(x, dtype=torch.float32), torch.tensor(y, dtype=torch.float32)


class CombustionData(Dataset):
    def __init__(self, X_full, y_full):
        super().__init__()
        self.X_full = X_full
        self.y_full = y_full

    def __len__(self):
        return len(self.X_full)

    def __getitem__(self, idx):
        input = self.X_full[idx]
        output = self.y_full[idx]
        return input, output

# %% [markdown]
# #### Hyperparameters

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Running on", device)
lr = 3e-4
batch_size = 256
epochs = 100
# Out:
# Running on cuda

# %% [markdown]
# #### Data preprocessing

# %%
data = process_data("volumes8/", 517, 8)
x, y = to_sequences(4, data)
print(x.shape)
print(y.shape)

# Scale the input to be between -1 and 1
xmin = x.min()
xmax = x.max()
ymin = y.min()
ymax = y.max()
xnormal = (x - xmin) / (xmax - xmin)
ynormal = (y - ymin) / (ymax - ymin)

# Initialize the dataset, split into train and validate sets, and create loaders
dataset = CombustionData(xnormal, ynormal)
train_data, val_data = random_split(dataset, [0.8, 0.2])
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(dataset=val_data, batch_size=batch_size, shuffle=False)
# Out:
# Processed data from first 10 time steps
# Processed data from first 20 time steps
# Processed data from first 30 time steps
# Processed data from first 40 time steps
# Processed data from first 50 time steps
# Processed data from first 60 time steps
# Processed data from first 70 time steps
# Processed data from first 80 time steps
# Processed data from first 90 time steps
# Processed data from first 100 time steps
# Processed data from first 110 time steps
# Processed data from first 120 time steps
# Processed data from first 130 time steps
# Processed data from first 140 time steps
# Processed data from first 150 time steps
# Processed data from first 160 time steps
# Processed data from first 170 time steps
# Processed data from first 180 time steps
# Processed data from first 190 time steps
# Processed data from first 200 time steps
# Processed data from first 210 time steps
# Processed data from first 220 time steps
# Processed data from first 230 time steps
# Processed data from first 240 time steps
# Processed data from first 250 time steps
# Processed data from first 260 time steps
# Processed data from first 270 time steps
# Processed data from first 280 time steps
# Processed data from first 290 time steps
# Processed data from first 300 time steps
# Processed data from first 310 time steps
# Processed data from first 320 time steps
# Processed data from first 330 time steps
# Processed data from first 340 time steps
# Processed data from first 350 time steps
# Processed data from first 360 time steps
# Processed data from first 370 time steps
# Processed data from first 380 time steps
# Processed data from first 390 time steps
# Processed data from first 400 time steps
# Processed data from first 410 time steps
# Processed data from first 420 time steps
# Processed data from first 430 time steps
# Processed data from first 440 time steps
# torch.Size([2004480, 8, 512])
# torch.Size([2004480, 512])

# %% [markdown]
# #### Model initialization

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size, 
                            num_layers=num_layers, batch_first=True)
        self.dropout = nn.Dropout(0.05)
        #self.fc1 = nn.Linear(hidden_size, 1024)
        self.fc2 = nn.Linear(hidden_size, input_size)

    def forward(self, x):
        x, _ = self.lstm(x)
        x = self.dropout(x[:, -1, :])
        #x = self.fc1(x)
        x = self.fc2(x)
        return x

model = LSTMModel(512, 1024, 3).to(device)

# %% [markdown]
# #### Train model

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=lr)
#scheduler = ReduceLROnPlateau(optimizer, 'min', factor=0.5, patience=3, verbose=True)

early_stop_count = 0
min_val_loss = float('inf')

train_hist = []
val_hist = []

for epoch in range(epochs):
    # Training
    model.train()
    train_losses = []
    for batch in train_loader:
        x_batch, y_batch = batch
        x_batch, y_batch = x_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()
        outputs = model(x_batch)
        loss = criterion(outputs, y_batch)
        train_losses.append(loss.item())
        loss.backward()
        optimizer.step()
    train_loss = np.mean(train_losses)
    train_hist.append(train_loss)

    # Validation
    model.eval()
    val_losses = []
    with torch.no_grad():
        for batch in test_loader:
            x_batch, y_batch = batch
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            outputs = model(x_batch)
            loss = criterion(outputs, y_batch)
            val_losses.append(loss.item())
    val_loss = np.mean(val_losses)
    val_hist.append(val_loss)
    #scheduler.step(val_loss)

    if val_loss < min_val_loss:
        min_val_loss = val_loss
        early_stop_count = 0
    else:
        early_stop_count += 1
 
    if early_stop_count >= 5:
        print("Early stopping!")
        break
    print(f"Epoch {epoch + 1}/{epochs}: Training Loss = {train_loss:.8f}, Validation Loss = {val_loss:.8f}")
# Out:
# Epoch 1/100: Training Loss = 0.00248295, Validation Loss = 0.00119181
# Epoch 2/100: Training Loss = 0.00087620, Validation Loss = 0.00053335
# Epoch 3/100: Training Loss = 0.00049843, Validation Loss = 0.00037088
# Epoch 4/100: Training Loss = 0.00038386, Validation Loss = 0.00028258
# Epoch 5/100: Training Loss = 0.00032504, Validation Loss = 0.00025779
# Epoch 6/100: Training Loss = 0.00028266, Validation Loss = 0.00021352
# Epoch 7/100: Training Loss = 0.00025223, Validation Loss = 0.00020052
# Epoch 8/100: Training Loss = 0.00023050, Validation Loss = 0.00017458
# Epoch 9/100: Training Loss = 0.00021246, Validation Loss = 0.00016223
# Epoch 10/100: Training Loss = 0.00021681, Validation Loss = 0.00015923
# Epoch 11/100: Training Loss = 0.00018890, Validation Loss = 0.00014534
# Epoch 12/100: Training Loss = 0.00017763, Validation Loss = 0.00013640
# Epoch 13/100: Training Loss = 0.00016781, Validation Loss = 0.00013476
# Epoch 14/100: Training Loss = 0.00015908, Validation Loss = 0.00012232
# Epoch 15/100: Training Loss = 0.00015113, Validation Loss = 0.00012019
# Epoch 60/100: Training Loss = 0.00006904, Validation Loss = 0.00006203
# Epoch 61/100: Training Loss = 0.00006937, Validation Loss = 0.00006129
# Epoch 62/100: Training Loss = 0.00006806, Validation Loss = 0.00006360
# Epoch 63/100: Training Loss = 0.00006771, Validation Loss = 0.00006107
# Epoch 64/100: Training Loss = 0.00006993, Validation Loss = 0.00006067
# Epoch 65/100: Training Loss = 0.00006706, Validation Loss = 0.00005997
# Epoch 66/100: Training Loss = 0.00006658, Validation Loss = 0.00005913
# Epoch 67/100: Training Loss = 0.00006619, Validation Loss = 0.00005938
# Epoch 68/100: Training Loss = 0.00006572, Validation Loss = 0.00005874
# Epoch 69/100: Training Loss = 0.00006732, Validation Loss = 0.00005891
# Epoch 70/100: Training Loss = 0.00006501, Validation Loss = 0.00005903
# Epoch 71/100: Training Loss = 0.00006597, Validation Loss = 0.00005893
# Epoch 72/100: Training Loss = 0.00006430, Validation Loss = 0.00005767
# Epoch 73/100: Training Loss = 0.00006404, Validation Loss = 0.00005737
# Epoch 74/100: Training Loss = 0.00006390, Validation Loss = 0.00005740
# Epoch 75/100: Training Loss = 0.00006326, Validation Loss = 0.00005681
# Epoch 76/100: Training Loss = 0.00006292, Validation Loss = 0.00005718
# Epoch 77/100: Training Loss = 0.00006256, Validation Loss = 0.00005836
# Epoch 78/100: Training Loss = 0.00006225, Validation Loss = 0.00005724
# Epoch 79/100: Training Loss = 0.00006199, Validation Loss = 0.00005663
# Epoch 80/100: Training Loss = 0.00006195, Validation Loss = 0.00005606
# Epoch 81/100: Training Loss = 0.00006151, Validation Loss = 0.00005579
# Epoch 82/100: Training Loss = 0.00006132, Validation Loss = 0.00005511
# Epoch 83/100: Training Loss = 0.00006088, Validation Loss = 0.00005542
# Epoch 84/100: Training Loss = 0.00006054, Validation Loss = 0.00005517
# Epoch 85/100: Training Loss = 0.00006029, Validation Loss = 0.00005520
# Epoch 86/100: Training Loss = 0.00006015, Validation Loss = 0.00005490
# Epoch 87/100: Training Loss = 0.00005991, Validation Loss = 0.00005528
# Epoch 88/100: Training Loss = 0.00005964, Validation Loss = 0.00005423
# Epoch 89/100: Training Loss = 0.00005935, Validation Loss = 0.00005419
# Epoch 90/100: Training Loss = 0.00005910, Validation Loss = 0.00005428
# Epoch 91/100: Training Loss = 0.00005893, Validation Loss = 0.00005423
# Epoch 92/100: Training Loss = 0.00005863, Validation Loss = 0.00005391
# Epoch 93/100: Training Loss = 0.00005840, Validation Loss = 0.00005447
# Epoch 94/100: Training Loss = 0.00005823, Validation Loss = 0.00005294
# Epoch 95/100: Training Loss = 0.00005794, Validation Loss = 0.00005289
# Epoch 96/100: Training Loss = 0.00005784, Validation Loss = 0.00005326
# Epoch 97/100: Training Loss = 0.00005750, Validation Loss = 0.00005273
# Epoch 98/100: Training Loss = 0.00005743, Validation Loss = 0.00005213
# Epoch 99/100: Training Loss = 0.00005716, Validation Loss = 0.00005365
# Epoch 100/100: Training Loss = 0.00005696, Validation Loss = 0.00005233

# %% [markdown]
# #### Plot loss

# %%
plt.figure(figsize=(15,5))
plt.plot(range(100), train_hist, label='Training loss')
plt.plot(range(100), val_hist, label='Validation loss')
plt.legend()
