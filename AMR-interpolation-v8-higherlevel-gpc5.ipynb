# %% [markdown]
# #### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import struct
import math

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from tqdm import tqdm

# %% [markdown]
# #### Useful functions/classes

# %%
### Takes a volume and splits it into cubes (blocks) of a specified dimension. Returns
### a list of torch tensors, each representing one block of the volume. If block_dim
### does not divide equally into the volume dimensions, creates blocks that extend past the
### dimensions of the volume, and populates the coordinates outside the volume with junk,
### which is an input to the function
def to_blocks(volume, block_dim, junk):
    
    xdim = volume.shape[0]
    ydim = volume.shape[1]
    zdim = volume.shape[2]

    x_steps = int(xdim // block_dim)
    if xdim % block_dim != 0:
        x_steps += 1
    y_steps = int(ydim / block_dim)
    if ydim % block_dim != 0:
        y_steps += 1
    z_steps = int(zdim / block_dim)
    if zdim % block_dim != 0:
        z_steps += 1
    num_blocks = int(x_steps * y_steps * z_steps)

    blocks = []

    for k in range(z_steps):
        for j in range(y_steps):
            for i in range(x_steps):

                x_lo = int(i * block_dim)
                y_lo = int(j * block_dim)
                z_lo = int(k * block_dim)

                block = torch.empty((block_dim, block_dim, block_dim))
                non_zero = False

                for z in range(block_dim):
                    for y in range(block_dim):
                        for x in range(block_dim):

                            if (x_lo + x) >= xdim:
                                block[x][y][z] = junk
                            elif (y_lo + y) >= ydim:
                                block[x][y][z] = junk
                            elif (z_lo + z) >= zdim:
                                block[x][y][z] = junk
                            else:
                                block[x][y][z] = volume[x_lo + x][y_lo + y][z_lo + z]
                                if volume[x_lo + x][y_lo + y][z_lo + z] != 0:
                                    non_zero = True
                
                if non_zero:
                    blocks.append(block)
                else: 
                    blocks.append("No data")

    return blocks


### Reads volume files in input_dir up to a maximum time step (max), and stores them in a nested
### list of format all_data[time_step][block_idx][x][y][z]
def process_data(input_dir, min_file, max_file, xdim, ydim, zdim, level, component):

    # Set up nested list to store data
    all_data = []

    for t in range(min_file, max_file): # iterate over each time step
        filename = input_dir + str(t) + "-whole-" + str(component) + "-" + str(level) + ".raw"
        with open(filename, "rb") as file:
            # storage array for volume data
            volume = np.empty((xdim, ydim, zdim))
            for k in range(zdim): # iterate through volume
                for j in range(ydim):
                    for i in range(xdim):
                        volume[i][j][k] = struct.unpack('<f', file.read(4))[0]
            all_data.append(volume)
        print("Processed data from time step",str(t))
        
    return all_data


### Assembles processed data into samples that can be used to train an autoencoder. Returns
### torch tensors with dimensions num_samples x 1 x block_dim x block_dim x block_dim; note
### that input and output are the same when training an autoencoder, so returns two instances
### of inputs
def create_samples(data, block_dim, junk):

    # Check if block_dim is a power of 2 (necessary for convolutional autoencoder)
    if not math.log2(block_dim).is_integer():
        print("Invalid block_dim! Dimension must be a power of 2.")
        return
    
    inputs = []
    empty_blocks = []
    empty_counter = 0
    for t in tqdm(range(len(data))):
        volume = data[t]
        blocks = to_blocks(volume, block_dim, junk)
        for l in range(len(blocks)):
            input = blocks[l]
            if input == "No data":
                empty_blocks.append([t, l])
                empty_counter += 1
            else:
                input = np.array(input)
                inputs.append(input)

    inputs = np.array(inputs)
    inputs = torch.tensor(inputs, dtype=torch.float32)
    inputs = inputs[:, None, :, :, :]
    print("Removed",str(empty_counter),"empty blocks from training set")
    return inputs, inputs, empty_blocks
    

class CombustionData(Dataset):
    def __init__(self, X_full, y_full):
        super().__init__()
        self.X_full = X_full
        self.y_full = y_full

    def __len__(self):
        return len(self.X_full)

    def __getitem__(self, idx):
        input = self.X_full[idx]
        output = self.y_full[idx]
        return input, output
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 114
#     110     print("Removed",str(empty_counter),"empty blocks from training set")
#     111     return inputs, inputs, empty_blocks
# --> 114 class CombustionData(Dataset):
#     115     def __init__(self, X_full, y_full):
#     116         super().__init__()
#
# NameError: name 'Dataset' is not defined

# %% [markdown]
# #### Hyperparameters

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Running on", device)
lr = 3e-4
batch_size = 128
epochs = 2500
# Out:
# Running on cuda

# %%
data = process_data("wholeVolumes-6-2/", 74, 84, 1024, 384, 384, 2, 6)
x, y, empties = create_samples(data, 64, 0)
print(x.shape)
print(y.shape)

# Scale the data to be between 0 and 1
xmin = x.min()
xmax = x.max()
ymin = y.min()
ymax = y.max()
xnormal = (x - xmin) / (xmax - xmin)
ynormal = (y - ymin) / (ymax - ymin)

# Initialize the dataset, and create data loader
dataset = CombustionData(xnormal, ynormal)
train_loader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True)
# Out:
# Processed data from time step 74
# Processed data from time step 75
# Processed data from time step 76
# Processed data from time step 77
# Processed data from time step 78
# Processed data from time step 79
# Processed data from time step 80
# Processed data from time step 81
# Processed data from time step 82
# Processed data from time step 83
# 100%|███████████████████████████████████████████████████████████████████████████████| 10/10 [3:20:58<00:00, 1205.89s/it]
# Removed 3907 empty blocks from training set
# torch.Size([1853, 1, 64, 64, 64])
# torch.Size([1853, 1, 64, 64, 64])

# %% [markdown]
# #### Model initialization

# %%
class ConvAutoencoder(nn.Module):
    def __init__(self):
        super(ConvAutoencoder, self).__init__()
        # Encoder
        self.encoder = nn.Sequential(
            nn.Conv3d(1, 128, kernel_size=3, stride=2, padding=1), # Output: 64 channels, block_dim/2
            nn.ReLU(),
            nn.Conv3d(128, 256, kernel_size=3, stride=2, padding=1), # Output: 128 channels, block_dim/4
            nn.ReLU(),
            nn.Conv3d(256, 512, kernel_size=3, stride=2, padding=1), # Output: 256 channels, block_dim/8
            nn.ReLU(),
            nn.Conv3d(512, 1024, kernel_size=3, stride=2, padding=1), # Output: 512 channels, block_dim/16
            #nn.ReLU(),
            #nn.Conv3d(512, 1024, kernel_size=3, stride=2, padding=1) # Output: 1024 channels, block_dim/32
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.ConvTranspose3d(1024, 512, kernel_size=3, stride=2, padding=1, output_padding=1), # Output: 512 channels, block_dim/16
            nn.ReLU(),
            nn.ConvTranspose3d(512, 256, kernel_size=3, stride=2, padding=1, output_padding=1), # Output: 256 channels, block_dim/8
            nn.ReLU(),
            nn.ConvTranspose3d(256, 128, kernel_size=3, stride=2, padding=1, output_padding=1), # Output: 128 channels, block_dim/4
            nn.ReLU(),
            nn.ConvTranspose3d(128, 1, kernel_size=3, stride=2, padding=1, output_padding=1), # Output: 64 channels, block_dim/2
            #nn.ReLU(),
            #nn.ConvTranspose3d(64, 1, kernel_size=3, stride=2, padding=1, output_padding=1), # Output: 1 channel, block_dim
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return encoded, decoded

model = ConvAutoencoder()

# %% [markdown]
# #### Train model

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=lr)

train_hist = []

for epoch in range(epochs):
    losses = []
    for sample in train_loader:
        # Get the inputs
        inputs = sample[0]

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        _, outputs = model(inputs)

        # Compute the loss
        loss = criterion(outputs, inputs)

        # Backward pass and optimize
        loss.backward()
        optimizer.step()
        losses.append(loss.item())
    train_hist.append(np.mean(losses))
    
    if (epoch+1) % 10 == 0:
        print(f"Epoch {epoch + 1}/{epochs}: Training Loss = {loss:.8f}")
# Out:
# Epoch 10/2500: Training Loss = 0.00055746
# Epoch 20/2500: Training Loss = 0.00046189
# Epoch 30/2500: Training Loss = 0.00053745
# Epoch 40/2500: Training Loss = 0.00047106
# Epoch 50/2500: Training Loss = 0.00303384
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 16
#      13 optimizer.zero_grad()
#      15 # Forward pass
# ---> 16 _, outputs = model(inputs)
#      18 # Compute the loss
#      19 loss = criterion(outputs, inputs)
#
# File ~/.conda/envs/interpolation/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/interpolation/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[5], line 32, in ConvAutoencoder.forward(self, x)
#      30 def forward(self, x):
#      31     encoded = self.encoder(x)
# ---> 32     decoded = self.decoder(encoded)
#      33     return encoded, decoded
#
# File ~/.conda/envs/interpolation/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/interpolation/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/.conda/envs/interpolation/lib/python3.12/site-packages/torch/nn/modules/container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File ~/.conda/envs/interpolation/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/interpolation/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/.conda/envs/interpolation/lib/python3.12/site-packages/torch/nn/modules/conv.py:1100, in ConvTranspose3d.forward(self, input, output_size)
#    1095 num_spatial_dims = 3
#    1096 output_padding = self._output_padding(
#    1097     input, output_size, self.stride, self.padding, self.kernel_size,  # type: ignore[arg-type]
#    1098     num_spatial_dims, self.dilation)  # type: ignore[arg-type]
# -> 1100 return F.conv_transpose3d(
#    1101     input, self.weight, self.bias, self.stride, self.padding,
#    1102     output_padding, self.groups, self.dilation)
#
# KeyboardInterrupt:

# %% [markdown]
# #### Plot loss

# %%
plt.figure(figsize=(15,5))
plt.plot(range(1891), train_hist, label='Training loss')
plt.legend()

# %% [markdown]
# #### Calc size of model

# %%
param_size = 0
for param in model.parameters():
    param_size += param.nelement() * param.element_size()
buffer_size = 0
for buffer in model.buffers():
    buffer_size += buffer.nelement() * buffer.element_size()
size_all_mb = (param_size + buffer_size) / 1024**2
print('model size: {:.3f}MB'.format(size_all_mb))
# Out:
# model size: 141.787MB

# %% [markdown]
# #### Save model

# %%
torch.save(model.state_dict(), "testModels/model1.pt")

# %% [markdown]
# #### Generate timestep using learned model

# %%
def generate_output(obs, model, step, block_dim, junk):

    # Translate step from filename to actual position
    step = step - 74
    
    preds = []

    tdata = obs[step]
    xdim = tdata.shape[0]
    ydim = tdata.shape[1]
    zdim = tdata.shape[2]
    blocks = to_blocks(tdata, block_dim, junk)
    
    # Generate a prediction for each location using the model
    for l in range(len(blocks)):
        input = blocks[l]
        if input == "No data":
            pred = np.zeros((1, block_dim, block_dim, block_dim))
        else: 
            input = input[None, :, :, :]
            normal_input = (input - xmin) / (xmax - xmin)
            _, pred = model(normal_input)
            pred = pred.cpu().detach().numpy()
        
        preds.append(pred)

    # Unpack preds and reshape to be one volume
    preds = np.array(preds)
    preds = torch.tensor(preds, dtype=torch.float32).squeeze()
    preds = preds * (ymax - ymin) + ymin
    print(preds.shape)

    x_steps = int(xdim // block_dim)
    if xdim % block_dim != 0:
        x_steps += 1
    y_steps = int(ydim / block_dim)
    if ydim % block_dim != 0:
        y_steps += 1
    z_steps = int(zdim / block_dim)
    if zdim % block_dim != 0:
        z_steps += 1

    prediction = np.empty((xdim, ydim, zdim))
    block_num = 0

    for k in range(z_steps):
        for j in range(y_steps):
            for i in range(x_steps):
                x_lo = int(i * block_dim)
                y_lo = int(j * block_dim)
                z_lo = int(k * block_dim)
                for z in range(block_dim):
                    for y in range(block_dim):
                        for x in range(block_dim):
                            if (x_lo + x) < xdim and (y_lo + y) < ydim and (z_lo + z) < zdim:
                                prediction[x_lo + x][y_lo + y][z_lo + z] = preds[block_num][x][y][z]
                block_num += 1

    return prediction


# Retrieve and assemble the known output
def get_output(obs, step):

    # Translate step from filename to actual position
    step = step - 74

    return obs[step]

# %%
prediction = generate_output(data, model, 74, 32, 0)
actual = get_output(data, 74)
# Out:
# torch.Size([576, 32, 32, 32])

# %%
def calc_mse(actual, predicted):

    xdim = actual.shape[0]
    ydim = actual.shape[1]
    zdim = actual.shape[2]

    sum = 0

    for k in range(zdim):
        for j in range(ydim):
            for i in range(xdim):
                sq = (actual[i][j][k] - predicted[i][j][k])**2
                sum += sq

    mse = sum / (xdim * ydim * zdim)

    return mse

mse = calc_mse(actual, prediction)
rmse = mse**0.5
print(rmse)
# Out:
# 13.0908178795153

# %% [markdown]
# #### Write prediction and actual to be visualized

# %%
def write_to_visualize(volume, path, out_file):
    filename = path + out_file
    with open(filename, "wb") as file:
        volume.tofile(file)

delta = actual - prediction

write_to_visualize(prediction, "toVisualize/", "compression-prediction.raw")
write_to_visualize(actual, "toVisualize/", "compression-actual.raw")
write_to_visualize(delta, "toVisualize/", "compression-delta.raw")
